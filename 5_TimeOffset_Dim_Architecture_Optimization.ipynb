# %% [markdown]
# This code explore the output of optimization for TimeOffset and Model Architecture

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Goodness of fit of time contrastive learning models

# %%
neuro_path = '/Users/elie/Library/CloudStorage/Box-Box/ManipBerkeleyZF/neuro_PurWhi_WF/'
filename = '%s/GoodnessFit_countData_Modvar_TimeOffset1_Dim5.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset1_Dim5 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset2_Dim5.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset2_Dim5 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset3_Dim5.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset3_Dim5 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset4_Dim5.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset4_Dim5 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset5_Dim5.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset5_Dim5 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset1_Dim3.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset1_Dim3 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset1_Dim4.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset1_Dim4 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset1_Dim6.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset1_Dim6 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset1_Dim7.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset1_Dim7 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset1_Dim8.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset1_Dim8 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset1_Dim9.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset1_Dim9 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset1_Dim10.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset1_Dim10 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset1_Dim15.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset1_Dim15 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset1_Dim20.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset1_Dim20 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset1_Dim25.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset1_Dim25 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset1_Dim30.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset1_Dim30 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset1_Dim35.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset1_Dim35 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset1_Dim50.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset1_Dim50 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset1_Dim20.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset1_Dim20 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset2_Dim20.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset2_Dim20 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset3_Dim20.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset3_Dim20 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset4_Dim20.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset4_Dim20 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_TimeOffset5_Dim20.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset5_Dim20 = pickle.load(f)

# %%
TimeOffsetMat_Dim5 = np.vstack([TimeOffset1_Dim5['goodness_of_fit_valid'], TimeOffset2_Dim5['goodness_of_fit_valid'], TimeOffset3_Dim5['goodness_of_fit_valid'], TimeOffset4_Dim5['goodness_of_fit_valid'], TimeOffset5_Dim5['goodness_of_fit_valid']])
TimeOffsetMat_Dim20 = np.vstack([TimeOffset1_Dim20['goodness_of_fit_valid'], TimeOffset2_Dim20['goodness_of_fit_valid'], TimeOffset3_Dim20['goodness_of_fit_valid'], TimeOffset4_Dim20['goodness_of_fit_valid'], TimeOffset5_Dim20['goodness_of_fit_valid']])
DimMat_TimeOffset1 = np.vstack([TimeOffset1_Dim3['goodness_of_fit_valid'], TimeOffset1_Dim4['goodness_of_fit_valid'], TimeOffset1_Dim5['goodness_of_fit_valid'], TimeOffset1_Dim6['goodness_of_fit_valid'], TimeOffset1_Dim7['goodness_of_fit_valid'], TimeOffset1_Dim8['goodness_of_fit_valid'],TimeOffset1_Dim9['goodness_of_fit_valid'],TimeOffset1_Dim10['goodness_of_fit_valid'],TimeOffset1_Dim15['goodness_of_fit_valid'],TimeOffset1_Dim20['goodness_of_fit_valid'],TimeOffset1_Dim25['goodness_of_fit_valid'],TimeOffset1_Dim30['goodness_of_fit_valid'],TimeOffset1_Dim35['goodness_of_fit_valid'],TimeOffset1_Dim50['goodness_of_fit_valid']])

# %%
print(np.max(TimeOffsetMat_Dim5))
print(np.max(TimeOffsetMat_Dim20))
print(np.max(DimMat_TimeOffset1))
TimeOffsetMat_Dim20[0,5]
# Out:
# 1.2818852017063787
# 1.3829875516111614
# 1.3971067191163449
# 1.3816674210383058

# %%
np.array(TimeOffset2_Dim5['Filter_size'])*10
# Out:
# array([ 10,  50, 100, 150, 200, 360, 400, 500])

# %%
plt.figure(figsize=(10,10))
ax1= plt.subplot(2,2,1)
img1=ax1.imshow(TimeOffsetMat_Dim5, aspect = 'auto', vmin = 0, vmax=1.4, cmap ='viridis')
ax1.set_ylabel('Time Offset (ms)')
ax1.set_yticks(ticks=np.linspace(0,4,5),labels=[10,20,30,40,50])
ax1.set_xlabel('Filter size (ms)')
ax1.set_xticks(ticks=np.linspace(0,7,8), labels=np.array(TimeOffset2_Dim5['Filter_size'])*10) # *10 because units is in data points and we are sampling at 100Hz
ax1.set_title('Goodness of fit 5 dimensions')
plt.colorbar(img1)
ax2= plt.subplot(2,2,2)
img2=ax2.imshow(DimMat_TimeOffset1, aspect = 'auto', vmin = 0, vmax=1.4, cmap ='viridis')
ax2.set_ylabel('Dimensions')
ax2.set_yticks(ticks=np.linspace(0,13,14),labels=[3,4,5,6,7,8,9,10,15,20,25,30,35,50])
ax2.set_xlabel('Filter size (ms)')
ax2.set_xticks(ticks=np.linspace(0,7,8), labels=np.array(TimeOffset2_Dim5['Filter_size'])*10)# *10 because units is in data points and we are sampling at 100Hz
ax2.set_title('Goodness of fit Time Offset 10ms')
plt.colorbar(img2)
ax3= plt.subplot(2,2,3)
img3=ax3.imshow(TimeOffsetMat_Dim20, aspect = 'auto', vmin = 0, vmax=1.4, cmap ='viridis')
ax3.set_ylabel('Time Offset (ms)')
ax3.set_yticks(ticks=np.linspace(0,4,5),labels=[10,20,30,40,50])
ax3.set_xlabel('Filter size (ms)')
ax3.set_xticks(ticks=np.linspace(0,7,8), labels=np.array(TimeOffset2_Dim20['Filter_size'])*10) # *10 because units is in data points and we are sampling at 100Hz
ax3.set_title('Goodness of fit 20 dimensions')
plt.colorbar(img3)

# %%
plt.figure(figsize=(10,10))
ax1= plt.subplot(2,2,1)
img1=ax1.imshow(TimeOffsetMat_Dim5, aspect = 'auto', vmin = 1, vmax=1.4, cmap ='viridis')
ax1.set_ylabel('Time Offset (ms)')
ax1.set_yticks(ticks=np.linspace(0,4,5),labels=[10,20,30,40,50])
ax1.set_xlabel('Filter size (ms)')
ax1.set_xticks(ticks=np.linspace(0,7,8), labels=np.array(TimeOffset2_Dim5['Filter_size'])*10) # *10 because units is in data points and we are sampling at 100Hz
ax1.set_title('Goodness of fit 5 Dimensions')
plt.colorbar(img1)
ax2= plt.subplot(2,2,2)
img2=ax2.imshow(DimMat_TimeOffset1, aspect = 'auto', vmin = 1, vmax=1.4, cmap ='viridis')
ax2.set_ylabel('Dimensions')
ax2.set_yticks(ticks=np.linspace(0,13,14),labels=[3,4,5,6,7,8,9,10,15,20,25,30,35,50])
ax2.set_xlabel('Filter size (ms)')
ax2.set_xticks(ticks=np.linspace(0,7,8), labels=np.array(TimeOffset2_Dim5['Filter_size'])*10) # *10 because units is in data points and we are sampling at 100Hz
ax2.set_title('Goodness of fit Time Offset 10ms')
plt.colorbar(img2)
ax3= plt.subplot(2,2,3)
img3=ax3.imshow(TimeOffsetMat_Dim20, aspect = 'auto', vmin = 1, vmax=1.4, cmap ='viridis')
ax3.set_ylabel('Time Offset (ms)')
ax3.set_yticks(ticks=np.linspace(0,4,5),labels=[10,20,30,40,50])
ax3.set_xlabel('Filter size (ms)')
ax3.set_xticks(ticks=np.linspace(0,7,8), labels=np.array(TimeOffset2_Dim20['Filter_size'])*10) # *10 because units is in data points and we are sampling at 100Hz
ax3.set_title('Goodness of fit 20 Dimensions')
plt.colorbar(img3)

# %%
np.linspace(1,8,8)
# Out:
# array([1., 2., 3., 4., 5., 6., 7., 8.])

# %% [markdown]
# # Goodness of fit of models with behavioral contrastive learning

# %%
neuro_path = '/Users/elie/Library/CloudStorage/Box-Box/ManipBerkeleyZF/neuro_PurWhi_WF/'
filename = '%s/GoodnessFit_countData_Modvar_Behav_TimeOffset1_Dim5.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset1_Dim5 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_Behav_TimeOffset2_Dim5.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset2_Dim5 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_Behav_TimeOffset3_Dim5.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset3_Dim5 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_Behav_TimeOffset4_Dim5.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset4_Dim5 = pickle.load(f)

filename = '%s/GoodnessFit_countData_Modvar_Behav_TimeOffset5_Dim5.pkl' % (neuro_path)
with open(filename, 'rb') as f:
    TimeOffset5_Dim5 = pickle.load(f)

TimeOffsetMat_Dim5 = np.vstack([TimeOffset1_Dim5['goodness_of_fit_valid'], TimeOffset2_Dim5['goodness_of_fit_valid'], TimeOffset3_Dim5['goodness_of_fit_valid'], TimeOffset4_Dim5['goodness_of_fit_valid'], TimeOffset5_Dim5['goodness_of_fit_valid']])
print(np.max(TimeOffsetMat_Dim5))

plt.figure(figsize=(10,20))
ax1= plt.subplot(2,1,1)
img1=ax1.imshow(TimeOffsetMat_Dim5, aspect = 'auto', vmin = 0, vmax=1.4, cmap ='viridis')
ax1.set_ylabel('Time Offset (ms)')
ax1.set_yticks(ticks=np.linspace(0,4,5),labels=[10,20,30,40,50])
ax1.set_xlabel('Filter size (ms)')
ax1.set_xticks(ticks=np.linspace(0,7,8), labels=np.array(TimeOffset2_Dim5['Filter_size'])*10) # *10 because units is in data points and we are sampling at 100Hz
ax1.set_title('Goodness of fit 5 dimensions')
plt.colorbar(img1)
ax2= plt.subplot(2,1,2)
img1=ax2.imshow(TimeOffsetMat_Dim5, aspect = 'auto', vmin = 0, vmax=0.13, cmap ='viridis')
ax2.set_ylabel('Time Offset (ms)')
ax2.set_yticks(ticks=np.linspace(0,4,5),labels=[10,20,30,40,50])
ax2.set_xlabel('Filter size (ms)')
ax2.set_xticks(ticks=np.linspace(0,7,8), labels=np.array(TimeOffset2_Dim5['Filter_size'])*10) # *10 because units is in data points and we are sampling at 100Hz
ax2.set_title('Goodness of fit 5 dimensions')
plt.colorbar(img1)
# Out:
# 0.12744145990651073
